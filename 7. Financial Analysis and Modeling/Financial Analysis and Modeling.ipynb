# %% [markdown]
# <a href="https://colab.research.google.com/github/anumit-web/ML-Analytics-Portfolio-2024/blob/main/7.%20Financial%20Analysis%20and%20Modeling/Financial%20Analysis%20and%20Modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Artificial Intelligence
# # Machine Learning
# # Portfolio Project
# # #7
# # Financial Analysis and Modeling
# # Goal = Analyze financial data to create investment strategies or forecast financial performance
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# %% [markdown]
# # Branding statement

# %%
# https://i.ibb.co/zZswY34/Pink-hands-network-2.png

# %%
from IPython.display import Image
Image('https://i.ibb.co/zZswY34/Pink-hands-network-2.png')

# %% [markdown]
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# %% [markdown]
# # EDA, Exploratory Data Analysis

# %% [markdown]
# ## import libraries

# %%
print('Hello, Financial Analysis and Modeling')
# Out:
# Hello, Financial Analysis and Modeling

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Input data

# %%
input_data_df = pd.read_csv("https://raw.githubusercontent.com/anumit-web/ML-Analytics-Portfolio-2024/refs/heads/main/7.%20Financial%20Analysis%20and%20Modeling/datasets/NFLX.csv")

# %% [markdown]
# Goal analyze the result of AB testing for marketing campaign or website feature.

# %%
number_of_rows = input_data_df.shape[0]
number_of_columns = input_data_df.shape[1]
print("Numner of rows = ", number_of_rows)
print("Number of columns = ", number_of_columns)
# Out:
# Numner of rows =  1009
# Number of columns =  7

# %%
input_data_df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1  2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2  2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3  2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4  2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900

# %%
input_data_df.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 1004  2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 1005  2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 1006  2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 1007  2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 1008  2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#         Volume
# 1004  20047500
# 1005  22542300
# 1006  14346000
# 1007   9905200
# 1008   7782400

# %%
input_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1009 non-null   object
#  1   Open       1009 non-null   float64
#  2   High       1009 non-null   float64
#  3   Low        1009 non-null   float64
#  4   Close      1009 non-null   float64
#  5   Adj Close  1009 non-null   float64
#  6   Volume     1009 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 55.3+ KB

# %%
input_data_df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1009.000000  1009.000000  1009.000000  1009.000000  1009.000000
# mean    419.059673   425.320703   412.374044   419.000733   419.000733
# std     108.537532   109.262960   107.555867   108.289999   108.289999
# min     233.919998   250.649994   231.229996   233.880005   233.880005
# 25%     331.489990   336.299988   326.000000   331.619995   331.619995
# 50%     377.769989   383.010010   370.880005   378.670013   378.670013
# 75%     509.130005   515.630005   502.529999   509.079987   509.079987
# max     692.349976   700.989990   686.090027   691.690002   691.690002
#
#              Volume
# count  1.009000e+03
# mean   7.570685e+06
# std    5.465535e+06
# min    1.144000e+06
# 25%    4.091900e+06
# 50%    5.934500e+06
# 75%    9.322400e+06
# max    5.890430e+07

# %% [markdown]
# print column names

# %%
print(input_data_df.columns)
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
# Get all Column Header Labels as List
for column_headers in  input_data_df.columns:
    print(column_headers)
# Out:
# Date
# Open
# High
# Low
# Close
# Adj Close
# Volume

# %% [markdown]
# ## find list of all columns which have null values
# using SKIMPY

# %%
# Get the count of null values in each column
null_counts = input_data_df.isnull().sum()
print('Priniting count of null values = ')
print(null_counts)
# Out:
# Priniting count of null values =
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
try:
  import skimpy
except:
  # !pip install skimpy
  import skimpy

# %%
# ! pip install skimpy

# %%
from skimpy import skim

# %%
skim(input_data_df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 1009   │ │ float64     │ 5     │                                                          │
# │ │ Number of columns │ 7      │ │ string      │ 1     │                                                          │
# │ └───────────────────┴────────┘ │ int64       │ 1     │                                                          │
# │                                └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━┳━━━━━┳━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━┓  │
# │ ┃ column_name  ┃ NA  ┃ NA %  ┃ mean    ┃ sd      ┃ p0      ┃ p25     ┃ p50     ┃ p75     ┃ p100     ┃ hist   ┃  │
# │ ┡━━━━━━━━━━━━━━╇━━━━━╇━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━┩  │
# │ │ Open         │   0 │     0 │   419.1 │   108.5 │   233.9 │   331.5 │   377.8 │   509.1 │    692.3 │ ▃▇▂▅▂▁ │  │
# │ │ High         │   0 │     0 │   425.3 │   109.3 │   250.6 │   336.3 │     383 │   515.6 │      701 │ ▅▇▂▆▂▁ │  │
# │ │ Low          │   0 │     0 │   412.4 │   107.6 │   231.2 │     326 │   370.9 │   502.5 │    686.1 │ ▅▇▂▆▂▁ │  │
# │ │ Close        │   0 │     0 │     419 │   108.3 │   233.9 │   331.6 │   378.7 │   509.1 │    691.7 │ ▃▇▂▅▂▁ │  │
# │ │ Adj Close    │   0 │     0 │     419 │   108.3 │   233.9 │   331.6 │   378.7 │   509.1 │    691.7 │ ▃▇▂▅▂▁ │  │
# │ │ Volume       │   0 │     0 │ 7571000 │ 5466000 │ 1144000 │ 4092000 │ 5934000 │ 9322000 │ 58900000 │   ▇▂   │  │
# │ └──────────────┴─────┴───────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴──────────┴────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name               ┃ NA      ┃ NA %       ┃ words per row                ┃ total words              ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ Date                      │       0 │          0 │                            1 │                     1009 │  │
# │ └───────────────────────────┴─────────┴────────────┴──────────────────────────────┴──────────────────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %% [markdown]
# ## find unique values by column names

# %%
# Find the number of unique values in both 'Name' and 'Age' columns
unique_values = input_data_df.nunique()
print(unique_values)
# Out:
# Date         1009
# Open          976
# High          983
# Low           989
# Close         988
# Adj Close     988
# Volume       1005
# dtype: int64

# %%
try:
  import summarytools
except:
  # !pip install summarytools
  import summarytools

# %%
# ! pip install summarytools

# %%
from summarytools import dfSummary

# %%
dfSummary(input_data_df)
# Out:
# <style type="text/css">
# #T_025e9 thead>tr>th {
#   text-align: left;
# }
# #T_025e9_row0_col0, #T_025e9_row1_col0, #T_025e9_row2_col0, #T_025e9_row3_col0, #T_025e9_row4_col0, #T_025e9_row5_col0, #T_025e9_row6_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_025e9_row0_col1, #T_025e9_row1_col1, #T_025e9_row2_col1, #T_025e9_row3_col1, #T_025e9_row4_col1, #T_025e9_row5_col1, #T_025e9_row6_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_025e9_row0_col2, #T_025e9_row1_col2, #T_025e9_row2_col2, #T_025e9_row3_col2, #T_025e9_row4_col2, #T_025e9_row5_col2, #T_025e9_row6_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_025e9_row0_col3, #T_025e9_row1_col3, #T_025e9_row2_col3, #T_025e9_row3_col3, #T_025e9_row4_col3, #T_025e9_row5_col3, #T_025e9_row6_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_025e9_row0_col4, #T_025e9_row1_col4, #T_025e9_row2_col4, #T_025e9_row3_col4, #T_025e9_row4_col4, #T_025e9_row5_col4, #T_025e9_row6_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_025e9_row0_col5, #T_025e9_row1_col5, #T_025e9_row2_col5, #T_025e9_row3_col5, #T_025e9_row4_col5, #T_025e9_row5_col5, #T_025e9_row6_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_025e9" class="dataframe">
#   <caption><strong>Data Frame Summary</strong><br>input_data_df<br>Dimensions: 1,009 x 7<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_025e9_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_025e9_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_025e9_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_025e9_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_025e9_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_025e9_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_025e9_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_025e9_row0_col1" class="data row0 col1" ><strong>Date</strong><br>[object]</td>
#       <td id="T_025e9_row0_col2" class="data row0 col2" >1. 2018-02-05<br>2. 2020-10-14<br>3. 2020-09-25<br>4. 2020-09-28<br>5. 2020-09-29<br>6. 2020-09-30<br>7. 2020-10-01<br>8. 2020-10-02<br>9. 2020-10-05<br>10. 2020-10-06<br>11. other</td>
#       <td id="T_025e9_row0_col3" class="data row0 col3" >1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>999 (99.0%)</td>
#       <td id="T_025e9_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_025e9_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_025e9_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_025e9_row1_col1" class="data row1 col1" ><strong>Open</strong><br>[float64]</td>
#       <td id="T_025e9_row1_col2" class="data row1 col2" >Mean (sd) : 419.1 (108.5)<br>min < med < max:<br>233.9 < 377.8 < 692.3<br>IQR (CV) : 177.6 (3.9)</td>
#       <td id="T_025e9_row1_col3" class="data row1 col3" >976 distinct values</td>
#       <td id="T_025e9_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_025e9_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_025e9_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_025e9_row2_col1" class="data row2 col1" ><strong>High</strong><br>[float64]</td>
#       <td id="T_025e9_row2_col2" class="data row2 col2" >Mean (sd) : 425.3 (109.3)<br>min < med < max:<br>250.6 < 383.0 < 701.0<br>IQR (CV) : 179.3 (3.9)</td>
#       <td id="T_025e9_row2_col3" class="data row2 col3" >983 distinct values</td>
#       <td id="T_025e9_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_025e9_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_025e9_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_025e9_row3_col1" class="data row3 col1" ><strong>Low</strong><br>[float64]</td>
#       <td id="T_025e9_row3_col2" class="data row3 col2" >Mean (sd) : 412.4 (107.6)<br>min < med < max:<br>231.2 < 370.9 < 686.1<br>IQR (CV) : 176.5 (3.8)</td>
#       <td id="T_025e9_row3_col3" class="data row3 col3" >989 distinct values</td>
#       <td id="T_025e9_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_025e9_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_025e9_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_025e9_row4_col1" class="data row4 col1" ><strong>Close</strong><br>[float64]</td>
#       <td id="T_025e9_row4_col2" class="data row4 col2" >Mean (sd) : 419.0 (108.3)<br>min < med < max:<br>233.9 < 378.7 < 691.7<br>IQR (CV) : 177.5 (3.9)</td>
#       <td id="T_025e9_row4_col3" class="data row4 col3" >988 distinct values</td>
#       <td id="T_025e9_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_025e9_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_025e9_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_025e9_row5_col1" class="data row5 col1" ><strong>Adj Close</strong><br>[float64]</td>
#       <td id="T_025e9_row5_col2" class="data row5 col2" >Mean (sd) : 419.0 (108.3)<br>min < med < max:<br>233.9 < 378.7 < 691.7<br>IQR (CV) : 177.5 (3.9)</td>
#       <td id="T_025e9_row5_col3" class="data row5 col3" >988 distinct values</td>
#       <td id="T_025e9_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_025e9_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_025e9_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_025e9_row6_col1" class="data row6 col1" ><strong>Volume</strong><br>[int64]</td>
#       <td id="T_025e9_row6_col2" class="data row6 col2" >Mean (sd) : 7570685.0 (5465535.2)<br>min < med < max:<br>1144000.0 < 5934500.0 < 58904300.0<br>IQR (CV) : 5230500.0 (1.4)</td>
#       <td id="T_025e9_row6_col3" class="data row6 col3" >1,005 distinct values</td>
#       <td id="T_025e9_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_025e9_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Data Processing

# %% [markdown]
# convert date column to date data tupe

# %%
# print
input_data_df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1  2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2  2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3  2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4  2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900

# %%
input_data_df["Date"]=pd.to_datetime(input_data_df["Date"])

# %%
input_data_df.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1 2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2 2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3 2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4 2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900

# %%
input_data_df.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %% [markdown]
# change index to date tyoe and date column

# %%
input_data_df.index = input_data_df['Date']

# %%
input_data_df.head()
# Out:
#                  Date        Open        High         Low       Close  \
# Date
# 2018-02-05 2018-02-05  262.000000  267.899994  250.029999  254.259995
# 2018-02-06 2018-02-06  247.699997  266.700012  245.000000  265.720001
# 2018-02-07 2018-02-07  266.579987  272.450012  264.329987  264.559998
# 2018-02-08 2018-02-08  267.079987  267.619995  250.000000  250.100006
# 2018-02-09 2018-02-09  253.850006  255.800003  236.110001  249.470001
#
#              Adj Close    Volume
# Date
# 2018-02-05  254.259995  11896100
# 2018-02-06  265.720001  12595800
# 2018-02-07  264.559998   8981500
# 2018-02-08  250.100006   9306700
# 2018-02-09  249.470001  16906900

# %% [markdown]
# do NOT drop date column because we need it for model training for linear and random forest algorithms

# %%
# input_data_df = input_data_df.drop('Date', axis=1)
# where 1 is the axis number (0 for rows and 1 for columns.)

# %%
input_data_df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
#
#               Volume
# Date
# 2018-02-05  11896100
# 2018-02-06  12595800
# 2018-02-07   8981500
# 2018-02-08   9306700
# 2018-02-09  16906900

# %% [markdown]
# # Data Visualization 📊📈📉

# %% [markdown]
# ## create histogram

# %%
input_data_df.hist(bins=50, figsize=(25, 20))
# Out:
# array([[<Axes: title={'center': 'Open'}>,
#         <Axes: title={'center': 'High'}>],
#        [<Axes: title={'center': 'Low'}>,
#         <Axes: title={'center': 'Close'}>],
#        [<Axes: title={'center': 'Adj Close'}>,
#         <Axes: title={'center': 'Volume'}>]], dtype=object)

# %% [markdown]
# ## plot time series graphs for each column

# %%
input_data_df.plot(subplots=True, layout=(5,2), figsize=(18, 20))

# ( rows, coluumns)
# Out:
# array([[<Axes: xlabel='Date'>, <Axes: xlabel='Date'>],
#        [<Axes: xlabel='Date'>, <Axes: xlabel='Date'>],
#        [<Axes: xlabel='Date'>, <Axes: xlabel='Date'>],
#        [<Axes: xlabel='Date'>, <Axes: xlabel='Date'>],
#        [<Axes: xlabel='Date'>, <Axes: xlabel='Date'>]], dtype=object)

# %% [markdown]
# # Data Calculations

# %% [markdown]
# ## strategy
# 1. Select one of the columns to test and train = high, low, volumne
# 2. Select input data into test and train
# 3. Run your models
#     a. Linear regression
#     b. Random Forest
# 4. Stop Words
# 5. Stemming
# 6. Lemmatization

# %% [markdown]
# Tokenization

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# date vs volume
#
# predict values of volume
#
# Linear regression is a statistical method used to model the relationship between a dependent variable and one or more independent variables
#
# independent variable = date
# dependent variable = volume

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
input_data_df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
#
#               Volume
# Date
# 2018-02-05  11896100
# 2018-02-06  12595800
# 2018-02-07   8981500
# 2018-02-08   9306700
# 2018-02-09  16906900

# %%
text_location = input_data_df.columns.get_loc('text')

# Create a new column 'Country'
input_data_df['text_processed'] = ""

# Insert the 'Country' column after the 'Name' column
input_data_df.insert(text_location + 1, 'text_processed', input_data_df.pop('text_processed'))

text_processed_location = input_data_df.columns.get_loc('text_processed')

# Create a new column 'Country'
input_data_df['text_processed_2'] = ""

# Insert the 'Country' column after the 'Name' column
input_data_df.insert(text_processed_location + 1, 'text_processed_2', input_data_df.pop('text_processed_2'))

text_processed_location_2 = input_data_df.columns.get_loc('text_processed_2')

# Create a new column 'Country'
input_data_df['text_processed_3'] = ""

# Insert the 'Country' column after the 'Name' column
input_data_df.insert(text_processed_location_2 + 1, 'text_processed_3', input_data_df.pop('text_processed_3'))


# print

input_data_df.head()

# print

input_data_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'text'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-72be031a1207> in <cell line: 1>()
# ----> 1 text_location = input_data_df.columns.get_loc('text')
#       2
#       3 # Create a new column 'Country'
#       4 input_data_df['text_processed'] = ""
#       5
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3796             ):
#    3797                 raise InvalidIndexError(key)
# -> 3798             raise KeyError(key) from err
#    3799         except TypeError:
#    3800             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'text'

# %% [markdown]
# ## 1. Lower case string

# %%
input_data_df['text_processed'] = input_data_df['text'].str.lower()

input_data_df.head()

# %% [markdown]
# ## 2. tokenize sentenses

# %%
import nltk
nltk.download('all')

# %%
from nltk.tokenize import word_tokenize

# Tokenize the 'text' column and put the result in a new column 'tokens'
input_data_df['text_processed'] = input_data_df['text_processed'].apply(word_tokenize)

input_data_df.head()

# %% [markdown]
# ## punctuation removal

# %%
input_data_df['text_processed_2'] = input_data_df['text_processed'].copy()

input_data_df.head()

# %%
input_data_df.loc[:, 'text_processed_3'] = input_data_df.loc[:, 'text_processed_2']

input_data_df.head()

# %%
import string

# input_data_df['text_processed_2'] = input_data_df['text_processed'].copy()

def remove_punctuation(tokens):

  tokens2 = []
  for word in tokens:
    #if (word in string.punctuation):
      #tokens.remove(word)
    if(word not in string.punctuation):
      tokens2.append(word)

  #return tokens
  return tokens2
  # return ""

# input_data_df['text_processed_2'] = input_data_df['text_processed']
input_data_df['text_processed_3'] = input_data_df['text_processed_3'].apply(remove_punctuation)

input_data_df.head(5)

# input_data_df['text', 'text_processed'].head()

# %% [markdown]
# ## stop words removal

# %%
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
def remove_stop_words(tokens):

  tokens2 = []
  for word in tokens:
    #if (word in stopwords.words('english')):
       #tokens.remove(word)
    if ( word not in stopwords.words('english')):
         tokens2.append(word)

  #return tokens
  return tokens2

input_data_df['text_processed_3'] = input_data_df['text_processed_3'].apply(remove_stop_words)

input_data_df.head()

# %% [markdown]
# ## 5. stemming

# %%
from nltk.stem import PorterStemmer
from nltk.stem.snowball import SnowballStemmer

# %%
porter_stemmer = PorterStemmer()
snowball_stemmer = SnowballStemmer("english") # use this algorithm as it is new version of porter

def stemwords_in_sentence(tokens):
  stemmed_words = []
  for word in tokens:
      stemmed_word = snowball_stemmer.stem(word)
      stemmed_words.append(stemmed_word)


  return stemmed_words

input_data_df['text_processed_3'] = input_data_df['text_processed_3'].apply(stemwords_in_sentence)

input_data_df.head()

# %% [markdown]
# ## 6. lemming

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()

def lemmatize_in_sentence(tokens):
  lemmatized_words = []
  for word in tokens:
      lemmatized_word =   lemmatizer.lemmatize(word)
      lemmatized_words.append(lemmatized_word)


  return lemmatized_words

input_data_df['text_processed_3'] = input_data_df['text_processed_3'].apply(lemmatize_in_sentence)

input_data_df.head()

# %% [markdown]
# ## 7. Join tokens into string

# %%
# input_data_df['text_processed_3'] =

# %%
text_processed_location_3 = input_data_df.columns.get_loc('text_processed_3')

# Create a new column 'Country'
input_data_df['text_processed_4'] = ""

# Insert the 'Country' column after the 'Name' column
input_data_df.insert(text_processed_location_3 + 1, 'text_processed_4', input_data_df.pop('text_processed_4'))

# %%
input_data_df['text_processed_4'] = input_data_df['text_processed_3'].apply(lambda token: ' '.join(token))

# %%
input_data_df.head()

# %% [markdown]
# ## Change column names

# %% [markdown]
# ## fill mean average values in rows and columns

# %% [markdown]
# ## Process combined data from control group and test group

# %% [markdown]
# # Data Calculations

# %% [markdown]
# ## Find sentiment of tweets and posts

# %% [markdown]
# ## VADER (Valence Aware Dictionary and sEntiment Reasoner)

# %% [markdown]
# negative, neutral, and positive scores
#
# compound score can range from -1 to 1.

# %%
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
sia = SentimentIntensityAnalyzer()

# %%
sia.polarity_scores("Wow, NLTK is really powerful!")

# %%
sia.polarity_scores("I had a bad experience at the geocery store!")

# %%
sia.polarity_scores("I am going to office")

# %%
# create get_sentiment function

def get_sentiment(text):

    scores = sia.polarity_scores(text)

    if scores['compound'] > 0 :
        new_sentiment = 1
    if scores['compound'] == 0 :
        new_sentiment = 0
    if scores['compound'] < 0 :
        new_sentiment = -1

    return new_sentiment


# apply get_sentiment function

input_data_df['calculated_sentiment'] = input_data_df['text_processed_4'].apply(get_sentiment)

input_data_df.head()

# %%
# Group by the 'Name' column and count the number of rows in each group
result =  input_data_df.groupby('calculated_sentiment').size()

print(result)

# %%
sentiment_location = input_data_df.columns.get_loc('sentiment')

# Create a new column 'Country'
input_data_df['sentiment_to_number'] = 9999999

# Insert the 'Country' column after the 'Name' column
input_data_df.insert(sentiment_location + 1, 'sentiment_to_number', input_data_df.pop('sentiment_to_number'))

input_data_df.head()

# %%
def convert_sentiment_to_number(sentiment):

  sentiment_number = 66666666

  if(sentiment == 'positive'):
    sentiment_number = 1
  if(sentiment == 'neutral'):
    sentiment_number = 0
  if(sentiment == 'negative'):
     sentiment_number = -1

  return sentiment_number
  # return ""

# input_data_df['text_processed_2'] = input_data_df['text_processed']
input_data_df['sentiment_to_number'] = input_data_df['sentiment'].apply(convert_sentiment_to_number)

input_data_df.head(5)

# %% [markdown]
# ## Confusion marrix

# %%
from sklearn.metrics import confusion_matrix

# %%
cf_matrix = confusion_matrix(input_data_df['sentiment_to_number'],
                             input_data_df['calculated_sentiment'])
print(cf_matrix)

# %%
from sklearn.metrics import classification_report

print(classification_report(input_data_df['sentiment_to_number'], input_data_df['calculated_sentiment']))

# %%
import seaborn as sns
sns.heatmap(cf_matrix, annot=True)

# %%
sns.heatmap(cf_matrix/np.sum(cf_matrix), annot=True,
            fmt='.2%', cmap='Blues')

# %%
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = [“{0:0.0f}”.format(value) for value in
                cf_matrix.flatten()]
group_percentages = [“{0:.2%}”.format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f”{v1}\n{v2}\n{v3}” for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')

# %% [markdown]
# Conversion Rate
#
# Conversion Rate = (Number of Conversions / Number of Visitors) x 100

# %% [markdown]
# add new columns
# normalized = value between 0 and 1
# percent = value between 0 and 100

# %%
combined_data_df['CTR_Normalized'] = 0
combined_data_df['CTR_Percent'] = 0
combined_data_df['CR_Normalized'] = 0
combined_data_df['CR_Percent'] = 0

#print
combined_data_df.head()

# %%
combined_data_df['CTR_Normalized'] = (combined_data_df['Clicks'] /
                      combined_data_df['Impressions'])

combined_data_df['CTR_Percent'] = (combined_data_df['Clicks'] /
                      combined_data_df['Impressions']) * 100

# print
combined_data_df.head()

# %%
combined_data_df['CR_Normalized'] = (combined_data_df['Purchases'] /
                      combined_data_df['Clicks'])

combined_data_df['CR_Percent'] = (combined_data_df['Purchases'] /
                      combined_data_df['Clicks']) * 100


#print
combined_data_df.head()

# %%
#CTR

temp_df1 = combined_data_df.groupby('Campaign Name')['CTR_Normalized'].mean()

# %%
temp_df2 = combined_data_df.groupby('Campaign Name')['CR_Normalized'].mean()

# %%
temp_df3 = combined_data_df.groupby('Campaign Name')['CTR_Percent'].mean()

# %%
temp_df4 = combined_data_df.groupby('Campaign Name')['CR_Percent'].mean()

# %%
temp_df5 = pd.merge(temp_df1, temp_df2, on='Campaign Name')

#print
temp_df5

# %%
temp_df6 = pd.merge(temp_df3, temp_df4, on='Campaign Name')

# %%
temp_df7 = pd.merge(temp_df5, temp_df6, on='Campaign Name')

# print
temp_df7

# %%
calculations_df = temp_df7

# print
temp_df7

# %% [markdown]
# seperator

# %% [markdown]
# seperator

# %% [markdown]
# # Visualization

# %% [markdown]
# ## CTR , Click through rate

# %% [markdown]
# ### Bar chart of CTR

# %%
colors = sns.color_palette(['#06C', '#F4B678'])

sns.barplot(data=calculations_df, x='Campaign Name',
                    y='CTR_Percent', hue='Campaign Name', palette = colors, dodge=False)
plt.title('Average Metrics of CTR')
plt.show()

# %% [markdown]
# ### Box chart of CTR

# %%
colors = sns.color_palette(['#73C5C5', '#A30000'])

sns.boxplot(x='Campaign Name', y='CTR_Normalized', data=combined_data_df,
            hue='Campaign Name', dodge=False, palette = colors)
plt.title('CTR Distribution by Campaign')
plt.show()

# %% [markdown]
# ### Violin chart of CTR

# %%
colors = sns.color_palette(['#7CC674', '#F0AB00'])

sns.violinplot(x='Campaign Name', y='CTR_Normalized', data=combined_data_df,
            hue='Campaign Name', dodge=False, palette = colors)
plt.title('CTR Distribution by Campaign')
plt.show()

# %% [markdown]
# ## CR, Conversion rate

# %% [markdown]
# ### Bar chart of CR

# %%
colors = sns.color_palette(['#06C', '#F4B678'])

sns.barplot(data=calculations_df, x='Campaign Name',
                    y='CR_Percent', hue='Campaign Name', palette = colors, dodge=False)
plt.title('Average Metrics of CR')
plt.show()

# %% [markdown]
# ### Box chart of CR

# %%
colors = sns.color_palette(['#73C5C5', '#A30000'])

sns.boxplot(x='Campaign Name', y='CR_Normalized', data=combined_data_df,
            hue='Campaign Name', palette = colors, dodge=False)
plt.title('CR Distribution by Campaign')
plt.show()

# %% [markdown]
# ### Violin chart of CR

# %%
colors = sns.color_palette(['#7CC674', '#F0AB00'])

sns.violinplot(x='Campaign Name', y='CR_Normalized', data=combined_data_df,
            hue='Campaign Name', palette = colors, dodge=False)
plt.title('CR Distribution by Campaign')
plt.show()

# %% [markdown]
# # Analysis and Conclusions

# %% [markdown]
# **CTR (Click-Through Rate):**
#
# Visual Observation: The histogram for CTR shows a higher mean for the Test Campaign compared to the Control Campaign.
# The KDE line for the Test Campaign is consistently above that of the Control Campaign.
# There are more outliers on the right for the Test Campaign than for the Control Campaign.
# Conclusion: The Test Campaign has a higher CTR, indicating better engagement.
#
#
#
# **CR (Conversion Rate):**
#
# Visual Observation: The histogram for CR shows similar means for both Control and Test Campaigns, with the Test Campaign
# having a slightly lower mean. The KDE lines overlap considerably, indicating similar distributions.
# Conclusion: There is no significant difference in CR between the Control and Test Campaigns.

# %% [markdown]
# # The End 🛑
